# %%
pip install crewai langchain openai duckduckgo-search
# Out:
# ...
# n3.11/dist-packages (from langchain) (0.3.8)
# ...

# %%
# !set OPENAI_API_KEY="API KEY"

# %%
# !pip install langchain-community

# %%
# !pip install crewai langchain langchain-community langchain-core openai

# %%
pip install --upgrade crewai langchain langchain-community openai

# %%
import os
from langchain import OpenAI, LLMChain, PromptTemplate
from langchain_community.tools import DuckDuckGoSearchRun
from langchain.agents import initialize_agent, Tool

os.environ["OPENAI_API_KEY"] = "API KEY"

# Define the search tool
search_tool = DuckDuckGoSearchRun()
tools = [
    Tool(name="search", func=search_tool.run, description="Search the web")
]

# Initialize GPT
llm = OpenAI(temperature=0)

# Create an agent
agent = initialize_agent(tools, llm, agent="zero-shot-react-description", verbose=True)

# Run a query
response = agent.run("Find the most recent generative AI tools from 2025 and summarize them.")
print("\n📋 Agent Response:\n", response)
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-58-969685822> in <cell line: 0>()
#      19
#      20 # Run a query
# ---> 21 response = agent.run("Find the most recent generative AI tools from 2025 and summarize them.")
#      22 print("\n📋 Agent Response:\n", response)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     601             if len(args) != 1:
# ...

# %%
# STEP 1: Configure Git with your name and email
# !git config --global user.name "LCM-S25-3035"
# !git config --global user.email "komalnandal6@gmail.com"

# %%
# !git clone -b test https://github.com/LCM-S25-3035/TEPIS.git
# Out:
# Cloning into 'TEPIS'...
# remote: Enumerating objects: 385, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 385 (delta 49), reused 110 (delta 22), pack-reused 243 (from 1)
# Receiving objects: 100% (385/385), 31.67 MiB | 17.32 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
# !cp "/content/Crew_AI.ipynb" "/content/TEPIS/"
# Out:
# cp: cannot stat '/content/Crew_AI.ipynb': No such file or directory

# %%
# !ls /content

# %%
# %cd /content/TEPIS
# !git add "Crew_AI.ipynb"
# !git commit --amend --no-edit

# %%
from getpass import getpass
token = getpass("🔐 Enter GitHub Token: ")

# !git push --force https://LCM-S25-3035:{token}@github.com/LCM-S25-3035/TEPIS.git test

# %%
# !grep "sk-" Crew_AI.ipynb
